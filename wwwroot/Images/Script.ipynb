-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [dbfor_firstapi_practice]
GO

-- %%
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230808170838_initialLoad', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230808220419_addemailtoemployeemodel', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230809165826_emailaddress', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230809170324_addusermodel', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230809172032_new', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230816225858_addroletouser', N'6.0.18')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20230821172147_addtraineemodel', N'6.0.18')
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
SET IDENTITY_INSERT [dbo].[Employees] ON 
INSERT [dbo].[Employees] ([Id], [Name], [Address], [Salary], [EMail]) VALUES (1, N'Rimi', N'Dhahe', 5356, N'rimi@gmail.com')
INSERT [dbo].[Employees] ([Id], [Name], [Address], [Salary], [EMail]) VALUES (9, N'Abhi', N'NayaGaon', 4576, N'abhi@gmail.com')
INSERT [dbo].[Employees] ([Id], [Name], [Address], [Salary], [EMail]) VALUES (10, N'Shivangi', N'Mohali', 7869, N'shivi@gmail.com')
SET IDENTITY_INSERT [dbo].[Employees] OFF
GO

-- %% [markdown]
-- # [dbo].[Trainees]

-- %%
SET IDENTITY_INSERT [dbo].[Trainees] ON 
INSERT [dbo].[Trainees] ([Id], [Name], [Address], [Email], [Stipend]) VALUES (1, N'Ramneet', N'Dhahe', N'rimi@gmail.com', 6000)
INSERT [dbo].[Trainees] ([Id], [Name], [Address], [Email], [Stipend]) VALUES (5, N'Shivangi', N'Mohali', N'shivi@gmail.com', 6000)
INSERT [dbo].[Trainees] ([Id], [Name], [Address], [Email], [Stipend]) VALUES (6, N'Abhishek', N'nayagaon', N'abhi@gmail.com', 6000)
SET IDENTITY_INSERT [dbo].[Trainees] OFF
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
SET IDENTITY_INSERT [dbo].[Users] ON 
INSERT [dbo].[Users] ([Id], [Username], [Password], [ConfirmPassword], [Role]) VALUES (9, N'ramneet', N'Ramneet@123#', N'Ramneet@123#', N'Admin')
INSERT [dbo].[Users] ([Id], [Username], [Password], [ConfirmPassword], [Role]) VALUES (10, N'ramneet1', N'Ramneet@123#', N'Ramneet@123#', N'Employee')
INSERT [dbo].[Users] ([Id], [Username], [Password], [ConfirmPassword], [Role]) VALUES (11, N'ramneet2', N'Ramneet@123#', N'Ramneet@123#', N'Employee')
INSERT [dbo].[Users] ([Id], [Username], [Password], [ConfirmPassword], [Role]) VALUES (12, N'ramneet3', N'Ramneet@123#', N'Ramneet@123#', N'Trainee')
INSERT [dbo].[Users] ([Id], [Username], [Password], [ConfirmPassword], [Role]) VALUES (13, N'ramneet4', N'Ramneet@123#', N'Ramneet@123#', N'Trainee')
SET IDENTITY_INSERT [dbo].[Users] OFF
GO
